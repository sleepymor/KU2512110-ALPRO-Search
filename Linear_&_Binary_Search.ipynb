# %% [markdown]
# <a href="https://colab.research.google.com/github/sleepymor/KU2512110-ALPRO-Search/blob/main/Linear_%26_Binary_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def linear_search(arr, target):
  """
  Melakukan pencarian linear pada sebuah list.

  Args:
    arr: List yang akan dicari.
    target: Nilai yang ingin dicari.

  Returns:
    Indeks dari target jika ditemukan, None jika tidak ditemukan.
  """
  for i in range(len(arr)):
    if arr[i] == target:
      return i
  return None

# Contoh penggunaan
my_list = [10, 20, 30, 40, 50]
target_value = 30

result = linear_search(my_list, target_value)

if result is not None:
  print(f"Nilai {target_value} ditemukan pada indeks {result}")
else:
  print(f"Nilai {target_value} tidak ditemukan dalam list")

target_value_2 = 60
result_2 = linear_search(my_list, target_value_2)

if result_2 is not None:
  print(f"Nilai {target_value_2} ditemukan pada indeks {result_2}")
else:
  print(f"Nilai {target_value_2} tidak ditemukan dalam list")

# %%
def binary_search(arr, target):
  """
  Melakukan pencarian biner pada sebuah list yang sudah diurutkan.

  Args:
    arr: List yang sudah diurutkan yang akan dicari.
    target: Nilai yang ingin dicari.

  Returns:
    Indeks dari target jika ditemukan, None jika tidak ditemukan.
  """
  low = 0
  high = len(arr) - 1
  while low <= high:
    mid = (low + high) // 2
    if arr[mid] == target:
      return mid
    elif arr[mid] < target:
      low = mid + 1
    else:
      high = mid - 1
  return None

# Contoh penggunaan
my_sorted_list = [10, 20, 30, 40, 50]
target_value = 40

result = binary_search(my_sorted_list, target_value)

if result is not None:
  print(f"Nilai {target_value} ditemukan pada indeks {result}")
else:
  print(f"Nilai {target_value} tidak ditemukan dalam list")

target_value_2 = 60
result_2 = binary_search(my_sorted_list, target_value_2)

if result_2 is not None:
  print(f"Nilai {target_value_2} ditemukan pada indeks {result_2}")
else:
  print(f"Nilai {target_value_2} tidak ditemukan dalam list")
# Out:
# Nilai 40 ditemukan pada indeks 3
# Nilai 60 tidak ditemukan dalam list

# %% [markdown]
# Soal 1
# Buat program yang menggunakan linear search untuk mencari nama mahasiswa berdasarkan NIM.
# Program menampilkan hasil berupa nama mahasiswa jika NIM ditemukan, dan pesan "Data tidak ditemukan" jika tidak ada.
#
# mahasiswa = [
#     ["2310001", "Aulia"],
#     ["2310002", "Bagus"],
#     ["2310003", "Citra"],
#     ["2310004", "Dedi"],
#     ["2310005", "Eka"]
# ]
#
# Contoh:
# Input: Masukkan NIM yang dicari: 2310003
# Output: Nama mahasiswa adalah Citra
#
# Input: Masukkan NIM yang dicari: 2310010
# Output: Data tidak ditemukan

# %%
# Fungsi linear search
def linear_search(data, nim_cari):



# Data mahasiswa (list 2D)
mahasiswa = [
    ["2310001", "Aulia"],
    ["2310002", "Bagus"],
    ["2310003", "Citra"],
    ["2310004", "Dedi"],
    ["2310005", "Eka"]
]

# Program utama
nim_input = input("Masukkan NIM yang dicari: ")
print(linear_search(mahasiswa, nim_input))

# %% [markdown]
# Soal 2
# Buat program yang menggunakan binary search untuk mencari nilai tertentu pada daftar nilai mahasiswa.
# Data nilai harus dalam urutan menaik (ascending).
# Program menampilkan pesan "Nilai ditemukan pada indeks ke-X" atau "Nilai tidak ditemukan".
#
# nilai = [45, 56, 60, 65, 70, 75, 80, 82, 90, 95]
#
# Contoh:
# Input: Masukkan nilai yang dicari: 80
# Output: Nilai ditemukan pada indeks ke-6
#
# Input: Masukkan nilai yang dicari: 77
# Output: Nilai tidak ditemukan

# %%
# Fungsi binary search
def binary_search(data, nilai_cari):
    kiri = 0
    kanan = len(data) - 1



# Data nilai mahasiswa
nilai = [45, 56, 60, 65, 70, 75, 80, 82, 90, 95]

# Program utama
nilai_input = int(input("Masukkan nilai yang dicari: "))
print(binary_search(nilai, nilai_input))
